# %%
#TO-DO-LIST

todo_list = []

def show_menu():
    print("\n--- To-Do List Menu ---")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Delete Task")
    print("4. Exit")

while True:
    show_menu()
    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        task = input("Enter the task: ")
        todo_list.append(task)
        print("Task added!")

    elif choice == "2":
        if not todo_list:
            print("No tasks found.")
        else:
            print("\nYour To-Do List:")
            for i, task in enumerate(todo_list, 1):
                print(f"{i}. {task}")

    elif choice == "3":
        view_index = int(input("Enter the task number to delete: ")) - 1
        if 0 <= view_index < len(todo_list):
            removed = todo_list.pop(view_index)
            print(f"Removed: {removed}")
        else:
            print("Invalid task number.")

    elif choice == "4":
        print("Goodbye!")
        break

    else:
        print("Invalid choice. Please enter 1-4.")
# Out:
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: Playing Games
# Task added!
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: Studying
# Task added!
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 2
#
# Your To-Do List:
# 1. Playing Games
# 2. Studying
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 3
# Enter the task number to delete: 1
# Removed: Playing Games
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 2
#
# Your To-Do List:
# 1. Studying
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 4
# Goodbye!

# %%
#Calculator

def main():
    print("Welcome to the simple calculator!")

    while True:
        # Take input from the user
        num1 = float(input("Enter first number: "))
        operator = input("Enter operator (+, -, *, /): ")
        num2 = float(input("Enter second number: "))

        # Do the calculation
        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '/':
            if num2 == 0:
                print("Error: Cannot divide by zero.")
                continue
            result = num1 / num2
        else:
            print("Invalid operator!")
            continue

        # Show result
        print("Result:", result)

        # Ask to continue
        choice = input("Do you want to calculate again? (yes/no): ")
        if choice.lower() != "yes":
            print("Goodbye!")
            break

# Run the calculator
main()
# Out:
# Welcome to the simple calculator!
# Enter first number: 345
# Enter operator (+, -, *, /): /
# Enter second number: 45
# Result: 7.666666666666667
# Do you want to calculate again? (yes/no): no
# Goodbye!

# %%
#Rock-Paper-Scissors Game

import random

print("Welcome to Rock-Paper-Scissors Game!")
choices = ['rock', 'paper', 'scissors']
user_score = 0
computer_score = 0

while True:
    # User Input
    user = input("Choose rock, paper, or scissors: ").lower()
    if user not in choices:
        print("Invalid choice. Try again.")
        continue

    # Computer Selection
    computer = random.choice(choices)

    # Game Logic
    print(f"You chose {user}, computer chose {computer}")
    if user == computer:
        print("It's a tie!")
    elif (user == "rock" and computer == "scissors") or \
         (user == "scissors" and computer == "paper") or \
         (user == "paper" and computer == "rock"):
        print("You win!")
        user_score += 1
    else:
        print("You lose!")
        computer_score += 1

    # Score Tracking
    print(f"Score -> You: {user_score}, Computer: {computer_score}")

    # Play Again
    play_again = input("Do you want to play another round? (yes/no): ").lower()
    if play_again != 'yes':
        break

print("Thanks for playing!")
# Out:
# Welcome to Rock-Paper-Scissors Game!
# Choose rock, paper, or scissors: rock
# You chose rock, computer chose rock
# It's a tie!
# Score -> You: 0, Computer: 0
# Do you want to play another round? (yes/no): yes
# Choose rock, paper, or scissors: paper
# You chose paper, computer chose paper
# It's a tie!
# Score -> You: 0, Computer: 0
# Do you want to play another round? (yes/no): yes
# Choose rock, paper, or scissors: rock
# You chose rock, computer chose rock
# It's a tie!
# Score -> You: 0, Computer: 0
# Do you want to play another round? (yes/no): yes
# Choose rock, paper, or scissors: scissors
# You chose scissors, computer chose paper
# You win!
# Score -> You: 1, Computer: 0
# Do you want to play another round? (yes/no): no
# Thanks for playing!
